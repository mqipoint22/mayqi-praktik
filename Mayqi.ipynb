# %%
Nama = input("nama :")
print ("nama ku", Nama)
# Out:
# nama :Budi
# nama ku Budi

# %%
print("nama: Muhammad mayqi")
print("NIM:2505060043")
print("TTL:Magelang 29 April 2007")
print("Alamat:joho,Dukun,Dukun")
print("Kelamin:laki-laki")
print("Hobi:melukis")
#print:untuk awalan
#hastag untuk menampilkan judul, tanpa pengaruh
print(4+0)
print(5-1)
print(2*2)
print(8/2)
#tanda + untuk proses tambah sama
#tanda - proses pengurangan
#tanda * proses perkalian pengganti x
#tanda / proses pembagian
# Out:
# nama: Muhammad mayqi
# NIM:2505060043
# TTL:Magelang 29 April 2007
# Alamat:joho,Dukun,Dukun
# Kelamin:laki-laki
# Hobi:melukis
# 4
# 4
# 4
# 4.0
